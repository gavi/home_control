# %%
import guidance
from guidance import select, models, gen

model = models.LlamaCpp('/Users/gavi/.cache/lm-studio/models/TheBloke/zephyr-7B-beta-GGUF/zephyr-7b-beta.Q8_0.gguf')

# %%
lm =  model + f"Do you want a joke or a poem? A {select(['joke', 'poem'], name='answer')}.\n"
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>Do you want a joke or a poem? A<span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> joke</span>.
# </pre>

# %% [markdown]
# We can extract the items by naming them

# %%
lm.get('answer')
# Out:
# 'joke'

# %%
devices = ["lights", "thermostat", "television", "none"]
actions = ["none","turn on", "turn off", "dim", "brighten", "set temperature", "change channel", "adjust volume"]
input = "My man, increase the volume of television"
input = "tv off"

lm = model + f'''You are a home assistant.You can choose one of these devices and actions - devices{devices} actions: {actions} The input from the user is -{input}. device:"{gen('device',stop='`')}",action:"{gen('action',stop='"')}"'''
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>You are a home assistant.You can choose one of these devices and actions - devices[&#x27;lights&#x27;, &#x27;thermostat&#x27;, &#x27;television&#x27;, &#x27;none&#x27;] actions: [&#x27;none&#x27;, &#x27;turn on&#x27;, &#x27;turn off&#x27;, &#x27;dim&#x27;, &#x27;brighten&#x27;, &#x27;set temperature&#x27;, &#x27;change channel&#x27;, &#x27;adjust volume&#x27;] The input from the user is -tv off. device<span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>:&quot;</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>te</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>lev</span><span style='background-col
# ...
